# %%
#importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import scipy.stats as sts
from scipy.stats.stats import pearsonr
from sklearn.linear_model import LinearRegression
from matplotlib.pyplot import figure
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf

# %%
#Reading the data
channel= pd.read_csv('yt_data_usa_channel_analysis.txt')

# %%
channel.head(5)
# Out:
#    Unnamed: 0                                 channelTitle  view_count  \
# 0           0                                   #TeamTrees      809044
# 1           1  (G)I-DLE (여자)아이들 (Official YouTube Channel)    45121844
# 2           2                                10 News First     4745924
# 3           3                                 10 Tampa Bay      355723
# 4           4                                  100 Thieves     2665623
#
#      Likes  Dislikes  Comments  Response_Percentage  LikesPercentage  \
# 0    56071       444      3770             6.985405         6.930525
# 1  1136612     34211    169469             2.594803         2.518984
# 2    46289      5489     15091             1.090999         0.975342
# 3      843        95       302             0.263688         0.236982
# 4   165707      2055     11238             6.293538         6.216445
#
#    DislikesPercentage  CommentsPercentage
# 0            0.054880            0.465982
# ...

# %%
#adding a column in the youtbe dataset to count the number of words in the ChannelTitle and customer engagement
#counting spaces and adding 1 to it
#customer engagement can be seen as both positive and negative that is likes and dislikes
channel['channel_wordcount'] = channel['channelTitle'].str.count(' ') + 1
channel['engagement']= channel['Likes']+ channel['Dislikes']

# %%
channel.head(5)
# Out:
#    Unnamed: 0                                 channelTitle  view_count  \
# 0           0                                   #TeamTrees      809044
# 1           1  (G)I-DLE (여자)아이들 (Official YouTube Channel)    45121844
# 2           2                                10 News First     4745924
# 3           3                                 10 Tampa Bay      355723
# 4           4                                  100 Thieves     2665623
#
#      Likes  Dislikes  Comments  Response_Percentage  LikesPercentage  \
# 0    56071       444      3770             6.985405         6.930525
# 1  1136612     34211    169469             2.594803         2.518984
# 2    46289      5489     15091             1.090999         0.975342
# 3      843        95       302             0.263688         0.236982
# 4   165707      2055     11238             6.293538         6.216445
#
#    DislikesPercentage  CommentsPercentage  channel_wordcount  engagement
# ...

# %%
import statsmodels.formula.api as smf

# %%
#Finding which variables are essential in view count with the help of regression
mr1= smf.ols('view_count ~ Likes + Dislikes + Comments+ Response_Percentage+ LikesPercentage+ DislikesPercentage+ CommentsPercentage+ channel_wordcount+ engagement', channel).fit()
print(mr1.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:             view_count   R-squared:                       0.856
# Model:                            OLS   Adj. R-squared:                  0.856
# Method:                 Least Squares   F-statistic:                     2989.
# Date:                Sun, 24 Apr 2022   Prob (F-statistic):               0.00
# Time:                        19:19:13   Log-Likelihood:                -63079.
# No. Observations:                3529   AIC:                         1.262e+05
# Df Residuals:                    3521   BIC:                         1.262e+05
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept            8.341e+06   6.46e+05     12.920      0.000    7.08e+06    9.61e+06
# ...

# %%
#comments percentage and chennel wordcount don't seem to play an important factor in 
#determining the views of a video

#rest everything else seems important
